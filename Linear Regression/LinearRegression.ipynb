# %% [markdown]
# ### Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year coming years

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("C:/Users/ryan.e/Documents/MachineLearning/Linear Regression/canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df.rename(columns={'per capita income (US$)': 'income'}, inplace=True)

# %%
# %matplotlib inline
plt.xlabel("Year")
plt.ylabel("Per Capita Income")
plt.scatter(df['year'], df['income'], color='red', marker='+')
plt.plot(df['year'], reg.predict(df[['year']]), color='blue', label='Regression line')
plt.show()

# %% [markdown]
# ##### predicting for the year 2025

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df.income)
# Out:
# LinearRegression()

# %%
print(df.columns.tolist())
# Out:
# ['year', 'income']

# %%
reg.predict([[2025]])
# Out:
# C:\Users\ryan.e\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45431.01947053])

# %%
# m is slope of the graph
reg.coef_
# Out:
# array([828.46507522])

# %%
# b is the Y Intercept
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
# price = slope * area + Y Intercept
# y = mx + b
828.46507522*2025+(-1632210.7578554575)
# Out:
# 45431.01946504251

# %% [markdown]
# #### Generate CSV file with list of years for prediction

# %%
year_df.rename(columns={'Years': 'year'}, inplace=True)

year_df = pd.read_csv("C:/Users/ryan.e/Documents/MachineLearning/Linear Regression/Years - Sheet1.csv")
year_df.head(3)
# Out:
#    Years
# 0   2017
# 1   2018
# 2   2019

# %%
print(reg.feature_names_in_)
# Out:
# ['year']

# %%
year_df.rename(columns={'Years': 'year'}, inplace=True)

# %%
p = reg.predict(year_df)
p
# Out:
# array([38803.29886875, 39631.76394397, 40460.22901919, 41288.69409442,
#        42117.15916964, 42945.62424486, 43774.08932009, 44602.55439531,
#        45431.01947053, 46259.48454575, 47087.94962098, 47916.4146962 ])

# %%
print(year_df.columns.tolist())
# Out:
# ['year']

# %%
df['prices_scaled'] = df['income'] / 100000

# %%
year_df['prices_scaled'] = p

# %%
year_df
# Out:
#     year  prices_scaled
# 0   2017   38803.298869
# 1   2018   39631.763944
# 2   2019   40460.229019
# 3   2020   41288.694094
# 4   2021   42117.159170
# 5   2022   42945.624245
# 6   2023   43774.089320
# 7   2024   44602.554395
# 8   2025   45431.019471
# 9   2026   46259.484546
# 10  2027   47087.949621
# 11  2028   47916.414696

# %%
print(df.columns.tolist())
# Out:
# ['year', 'income', 'prices_scaled']

# %%
print(year_df.columns.tolist())
# Out:
# ['year', 'prices_scaled']

# %%
# %matplotlib inline
plt.xlabel("Year")
plt.ylabel("Per Capita Income")
plt.scatter(year_df['year'], year_df['prices_scaled'],color='red',marker='+')
plt.plot(year_df['year'], reg.predict(year_df[['year']]), color='blue', label='Regression line')

# %% [markdown]
# #### Calculating Efficiency

# %%
 from sklearn.metrics import r2_score, mean_squared_error

# %%
   predictions = reg.predict(df[['year']])
   print("R² Score:", r2_score(df['income'], predictions))
   print("MSE:", mean_squared_error(df['income'], predictions))
# Out:
# R² Score: 0.890916917957032
# MSE: 15462739.061504772
